# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("tested.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
no_of_row = df.shape[0]
print(' No of row= ',no_of_row)
# Out:
#  No of row=  418

# %%
no_of_column = df.shape[1]
print(' No of columns= ',no_of_column)
# Out:
#  No of columns=  12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df=df[~(df['Fare'].isnull())]
df['Fare'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Name: Fare, Length: 417, dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          326
# Embarked         0
# dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 21.0    17
# 24.0    17
# 22.0    16
# 30.0    15
# 18.0    13
#         ..
# 76.0     1
# 28.5     1
# 22.5     1
# 62.0     1
# 38.5     1
# Name: count, Length: 78, dtype: int64

# %%
avg_age=df['Age'].mean()
avg_age
# Out:
# 30.181268882175228

# %%
df['Age']=df['Age'].fillna(avg_age)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          326
# Embarked         0
# dtype: int64

# %%
df["Cabin"].value_counts()
# Out:
# Cabin
# B57 B59 B63 B66    3
# B45                2
# C89                2
# C55 C57            2
# A34                2
#                   ..
# E52                1
# D30                1
# E31                1
# C62 C64            1
# C105               1
# Name: count, Length: 76, dtype: int64

# %%
df["Cabin"].isnull().sum()
# Out:
# 326

# %%
df.drop('Cabin',axis=1, inplace= True)

# %%
df.shape
# Out:
# (417, 11)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 417 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  417 non-null    int64
#  1   Survived     417 non-null    int64
#  2   Pclass       417 non-null    int64
#  3   Name         417 non-null    object
#  4   Sex          417 non-null    object
#  5   Age          417 non-null    float64
#  6   SibSp        417 non-null    int64
#  7   Parch        417 non-null    int64
#  8   Ticket       417 non-null    object
#  9   Fare         417 non-null    float64
#  10  Embarked     417 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 39.1+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   417.000000  417.000000  417.000000  417.000000  417.000000
# mean   1100.635492    0.364508    2.263789   30.181269    0.448441
# std     120.923774    0.481870    0.842077   12.562331    0.897568
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.000000    0.000000    1.000000   23.000000    0.000000
# 50%    1101.000000    0.000000    3.000000   30.181269    0.000000
# 75%    1205.000000    1.000000    3.000000   35.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  417.000000  417.000000
# mean     0.393285   35.627188
# std      0.982419   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# ### EDA

# %%
cat= [i for i in df.columns if df[i].dtype=='O']
cat
# Out:
# ['Name', 'Sex', 'Ticket', 'Embarked']

# %%
num_value
df.select_dtypes(exclude=['object']).columns.tolist()
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# ### univariate variable

# %%
plt.figure(figsize=[4,5])
sns.countplot(x= 'Survived', data= df, hue='Sex')
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.boxplot(x= 'Age', data= df)
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.boxplot(x= 'Age', data= df,hue='Sex')
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.histplot(x='Age',bins=10,data=df)
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.histplot(x='Age',bins=10,data=df, hue='Sex')
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.histplot(x='Fare',bins=10 ,data=df)
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.histplot(x='Fare',bins=10 ,data=df,hue='Sex')
plt.show()

# %% [markdown]
# ### Bivariate Variable

# %% [markdown]
# ###### cat_value/ num_values

# %%
plt.figure(figsize=[4,5])
sns.barplot(x="Sex", y="Age", data= df)
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.barplot(x="Embarked", y="Age", data= df)
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.barplot(x="Embarked", y="Age", data= df, hue='Sex')
plt.show()

# %% [markdown]
# ###### num_value/num_values

# %%
plt.figure(figsize=[4,5])
sns.scatterplot(x='Age' ,y='Fare', data=df)
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.scatterplot(x='Age' ,y='Fare', data=df, hue='Embarked')
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.scatterplot(x='Age' ,y='Fare', data=df, hue='Sex')
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.scatterplot(x='Pclass' ,y='Fare', data=df, hue='Sex')
plt.show()

# %%
plt.figure(figsize=[4,5])
sns.scatterplot(x='Pclass' ,y='Embarked', data=df, hue='Sex')
plt.show()

# %% [markdown]
# ##### Multivariate Variable

# %%
plt.figure(figsize=[6,7])
sns.pairplot(df, vars=['Age', 'Sex', 'Pclass', 'Fare'])
plt.show()

# %%
sns.pairplot(df, vars=['Age', 'Pclass', 'Fare'], hue='Sex')
plt.show()

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

correlation_matrix = df[numeric_columns].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='Greens', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
